# %%
print("jay ganesh")
# Out:
# jay ganesh

# %%
import pandas as pd
import numpy as np

# %%
user_data = pd.read_csv(r"D:\genrated_data_recomadation\genrated_data_recomandation\synthetic_user_data.csv")
video_data = pd.read_csv(r"D:\genrated_data_recomadation\genrated_data_recomandation\Synthetic_Video_Data.csv")

# %%
user_data
# Out:
#       user_id           country                                languages  \
# 0           1               1.0  American English,Latin American Spanish
# 1           2              39.0                         ,English,Persian
# 2           3  Select a Country                           English,Polish
# 3           4                75                          English,Italian
# 4           5             225.0                   Persian,Pashto,English
# ...       ...               ...                                      ...
# 1995     1996             181.0                                   ,Dutch
# 1996     1997             192.0       Persian,English,Turkish,Hindi,Urdu
# 1997     1998                83                              Blin,Pashto
# 1998     1999             225.0                           English pashto
# 1999     2000               103                 American English,English
#
#       beauty-&-fashion  football  entertainment  pets  music  funny  \
# ...
